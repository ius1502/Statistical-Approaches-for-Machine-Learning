# %%
L=[1,4,7,9,11]
print(L[0])
print(L[1])
print(L[2])
print(L[3])
print(L[4])

n=len(L)
mid_pos=n//2
print(mid_pos)

print(L[mid_pos])
# Out:
# 1
# 4
# 7
# 9
# 11
# 2
# 7

# %%
K=[2,4,5,6,8,9,12,14,15,17,19]

print(K[0])
print(K[1])
print(K[2])
print(K[3])
print(K[4])
print(K[5])
print(K[6])
print(K[7])
print(K[8])
print(K[9])
print(K[10])

n=len(K)
mid_pos=n//2
print(mid_pos)

print(K[mid_pos])
# Out:
# 2
# 4
# 5
# 6
# 8
# 9
# 12
# 14
# 15
# 17
# 19
# 5
# 9

# %%
K=[12,14,15,16,18,19,22,24,25,27,29,39,40,42,45,47,49]

print(K[0])
print(K[1])
print(K[2])
print(K[3])
print(K[4])
print(K[5])
print(K[6])
print(K[7])
print(K[8])
print(K[9])
print(K[10])
print(K[11])
print(K[12])
print(K[13])
print(K[14])
print(K[15])
print(K[16])

n=len(K)
mid_pos=n//2
print(mid_pos)

print(K[mid_pos])
# Out:
# 12
# 14
# 15
# 16
# 18
# 19
# 22
# 24
# 25
# 27
# 29
# 39
# 40
# 42
# 45
# 47
# 49
# 8
# 25

# %%
M=[12,14,15]

print(M[0])
print(M[1])
print(M[2])

n=len(M)
mid_pos=n//2
print(mid_pos)

print(M[mid_pos])
# Out:
# 12
# 14
# 15
# 1
# 14

# %%
N=[12,14,15,16,17]

print(N[0])
print(N[1])
print(N[2])
print(N[3])
print(N[4])

n=len(N)
mid_pos=n//2
print(mid_pos)

print(N[mid_pos])
# Out:
# 12
# 14
# 15
# 16
# 17
# 2
# 15

# %%
P=[12,14,15,16]
print(P[0])
print(P[1])
print(P[2])
print(P[3])

n=len(P)
midpos_1,midpos_2=n//2,n//2-1
print(midpos_1,midpos_2)

print(P[midpos_1],P[midpos_2])
# Out:
# 12
# 14
# 15
# 16
# 2 1
# 15 14

# %%
Q=[12,14,15,16,18,19]
print(Q[0])
print(Q[1])
print(Q[2])
print(Q[3])
print(Q[4])
print(Q[5])

n=len(Q)
midpos_1,midpos_2=n//2-1,n//2
print(midpos_1,midpos_2)

print(Q[midpos_1],Q[midpos_2])
# Out:
# 12
# 14
# 15
# 16
# 18
# 19
# 2 3
# 15 16

# %%
R=[12,14,15,16,18,19,20,22]
a)print the value of R[0],R[1],R[2],R[3],R[4]
b)print the index of mid positions of this list
c)print the value at index of mid position of this list

# %%
R=[12,14,15,16,18,19,20,22]
print(R[0])
print(R[1])
print(R[2])
print(R[3])
print(R[4])
print(R[5])
print(R[6])
print(R[7])

n=len(R)
midpos_1,midpos_2=n//2-1,n//2
print(midpos_1,midpos_2)

print(R[midpos_1],R[midpos_2])
# Out:
# 12
# 14
# 15
# 16
# 18
# 19
# 20
# 22
# 3 4
# 16 18

# %%
S=[12,14,15,16,18,19,20,22,24,27]

print(S[0])
print(S[1])
print(S[2])
print(S[3])
print(S[4])
print(S[5])
print(S[6])
print(S[7])
print(S[8])
print(S[9])

n=len(S)
midpos_1,midpos_2=n//2-1,n//2
print(midpos_1,midpos_2)

print(S[midpos_1],S[midpos_2])
# Out:
# 12
# 14
# 15
# 16
# 18
# 19
# 20
# 22
# 24
# 27
# 4 5
# 18 19
