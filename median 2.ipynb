# %%
U=[12,14,15,16,18,19,20,22,24,27,36,78,79,80,81,82,87,89,90,95,98]
print(U[0:])

n=len(U)
midpos_1,midpos_2=n//2-1,n//2
print(midpos_1,midpos_2)

print(U[midpos_1],U[midpos_2])
# Out:
# [12, 14, 15, 16, 18, 19, 20, 22, 24, 27, 36, 78, 79, 80, 81, 82, 87, 89, 90, 95, 98]
# 9 10
# 27 36

# %%
V=[12,14,15,16,18,19,20,22,24,27,36,78,79,80,81,82,87,89,90,95,98]
print(V[0:])

n=len(V)
if n%2==0:
    midpos1=n//2-1
    midpos2=n//2
    print(midpos1,midpos2)
    print(V[midpos1],V[midpos2])
else:
    midpos=n//2
    print(midpos)
    print(V[midpos])
# Out:
# [12, 14, 15, 16, 18, 19, 20, 22, 24, 27, 36, 78, 79, 80, 81, 82, 87, 89, 90, 95, 98]
# 10
# 36

# %%
W=[2,4,5,6,8,9,10,22,24,27,36,48,59,80,81,82,87,89,90,95,98,109,110,110,111,116,118,119,227,228,229,230,235]
print(W[0:])

n=len(W)
if n%2==0:
    midpos1=n//2-1
    midpos2=n//2
    print(midpos1,midpos2)
    print(W[midpos1],W[midpos2])
else:
    midpos=n//2
    print(midpos)
    print(W[midpos])
# Out:
# [2, 4, 5, 6, 8, 9, 10, 22, 24, 27, 36, 48, 59, 80, 81, 82, 87, 89, 90, 95, 98, 109, 110, 110, 111, 116, 118, 119, 227, 228, 229, 230, 235]
# 16
# 87

# %%
W=[2,4,5,6,8,9,10,22]

n=len(W)
if n%2==0:
    midpos1=n//2-1
    midpos2=n//2
    print(midpos1,midpos2)
    print(W[midpos1],W[midpos2])
    median=(W[midpos1]+W[midpos2])/2
    print("median of dataset is:",median)
else:
    midpos=n//2
    print(midpos)
    print(W[midpos])
    median=W[midpos]
    print("median of dataset is:",median)
# Out:
# 3 4
# 6 8
# median of dataset is: 7.0
