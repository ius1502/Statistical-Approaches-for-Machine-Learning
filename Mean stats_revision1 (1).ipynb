# %%
L=[1,4,7,9]
x=sum(L)
print("sum of all elements of list L is;",x)

y=len(L)
print("count of elements of list L is;",y)
# Out:
# sum of all elements of list L is; 21
# count of elements of list L is; 4

# %%
M=[14,42,17,19]
a=sum(M)
print(a)
b=len(M)
print("count of list M is;",b)
# Out:
# 92
# count of list M is; 4

# %%
p=[24,73,56,28,19,18,17,34,71]
x=sum(p)
y=len(p)
print("sum of all element is;",x)
print("count of all element is;",y)
print("mean is",x/y)
# Out:
# sum of all element is; 340
# count of all element is; 9
# mean is 37.77777777777778

# %%
q=[24,18,19,17,34,71]
x=sum(q)
y=len(q)
print(x)
print(y)
print("mean is;", x/y)
# Out:
# 183
# 6
# mean is; 30.5

# %%
S=[3,6,4,8]
x=sum(S)
y=len(S)
print("sum of all element of list is;",x)
print("count of all elements of list S is;",y)
print("mean is;",x/y)
# Out:
# sum of all element of list is; 21
# count of all elements of list S is; 4
# mean is; 5.25

# %%
F=[13,63,42,81]
x=sum(F)
y=len(F)
print("sum of all element of list is;",x)
print("count of all elements of list S is;",y)
print("mean is;",x/y)
# Out:
# sum of all element of list is; 199
# count of all elements of list S is; 4
# mean is; 49.75
